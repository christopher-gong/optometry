# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
from importHelpers.response import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

# %%
initial = pd.read_csv(r"data\\190819_file24_concat.csv", index_col=0, header=None).T
df = removeLowSTD(initial, 3)
pca = PCA(n_components=20)
principalComponents = pca.fit_transform(df)
principalDf = pd.DataFrame(data = principalComponents)

# %%
p = list(pca.inverse_transform(principalComponents)[0])
b = list(df.iloc[0])

# %%
# %matplotlib notebook
plt2 = plt.figure()
plt.plot(p)
plt.plot(b)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1e99ee135e9e> in <module>
# ----> 1 trialPCAB = np.array([[1.19029871, b,  1.95384968] for b in range(-2, 3)])
#       2 trialBackB = pca.inverse_transform(trialPCAB)
#       3 get_ipython().run_line_magic('matplotlib', 'notebook')
#       4 plt4 = plt.figure()
#       5 plt.plot(trialBackB[0])
#
# NameError: name 'np' is not defined
