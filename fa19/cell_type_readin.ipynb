# %%
import glob
import csv
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import Utilities as utils
import imp
from sklearn.decomposition import PCA as sklearnPCA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-63837951dbda> in <module>
#       4 from sklearn.cluster import KMeans
#       5 import matplotlib.pyplot as plt
# ----> 6 import Utilities as utils
#       7 import imp
#       8 from sklearn.decomposition import PCA as sklearnPCA
#
# ModuleNotFoundError: No module named 'Utilities'

# %%
imp.reload(utils)
## Load and normalize tables_a
filelist = utils.load_filelist("/home/april/IActData_Export/*")
tables_a, final_flist = utils.generate_table(filelist, rm_cap=True, return_flist=True)
#tables_a = utils.norm1(tables_a)
tables_a = utils.norm_meandepol_1(tables_a)

# %%
#load cell list & check
cell_labels = utils.readin_cell_labels('data/Cell_Types.csv')
utils.check_flist_match(final_flist, cell_labels)
# Out:
# All 400 traces match!

# %%
np.unique(cell_labels[:,1])
# Out:
# array(['AC', 'BB', 'DB', 'DB1', 'DB1 cone', 'DB1 or DB4B', 'DB2',
#        'DB2 cone', 'DB2 or DB3', 'DB2 or FMB', 'DB2 or ON', 'DB3',
#        'DB3 or DB4', 'DB3A', 'DB3B', 'DB3B cone', 'DB4', 'DB4 or DB3B',
#        'DB4 or DB5', 'DB5', 'DB5 or DB6', 'DB6', 'FMB', 'FMB cone',
#        'FMB cones', 'FMB or DB2', 'GBC', 'IMB', 'MB', 'OFF DB', 'ON',
#        'ON DB', 'RBC', 'RBC or DB6', 'RBC or ON', 'Unknown'],
#       dtype='<U13')

# %% [markdown]
# dbsub_categorization, dbsub_labels = utils.mark_cell_categories(cell_labels, 'DB_Subtypes')
# dsub_clusters = utils.apply_kmeans(12, tables_a)
# utils.plot_clusters, dbsub_categorization, dbsub_labels)

# %%
imp.reload(utils)
scaled = utils.scale_dt(tables_a)
plt.plot(scaled[1])

# %%
plt.plot(tables_a[1])

# %% [markdown]
# ## DB/NON (2 clusters)

# %%
db_categorization, db_labels = utils.mark_cell_categories(cell_labels, 'DB')
db_clusters = utils.apply_kmeans(2, tables_a)
utils.plot_clusters(tables_a, db_clusters, db_categorization, db_labels)

# %%
db_categorization, db_labels = utils.mark_cell_categories(cell_labels, 'DB')
db_clusters = utils.agglom_clust(2, tables_a)
utils.plot_clusters(tables_a, db_clusters, db_categorization, db_labels)

# %% [markdown]
# ## On Off

# %%
onoff_categorization, onoff_labels = utils.mark_cell_categories(cell_labels, 'On_Off')
onoff_clusters = utils.apply_kmeans(12, tables_a)
utils.plot_clusters(tables_a, onoff_clusters, onoff_categorization, onoff_labels)

# %%
imp.reload(utils)
onoff_clusters = utils.agglom_clust(12, tables_a)
utils.plot_clusters(tables_a, onoff_clusters, onoff_categorization, onoff_labels)

# %% [markdown]
# ## RBC/Non

# %%
rbc_categorization, rbc_labels = utils.mark_cell_categories(cell_labels, 'RBC')
rbc_clusters = utils.apply_kmeans(12, tables_a)
utils.plot_clusters(tables_a, rbc_clusters, rbc_categorization, rbc_labels)

# %% [markdown]
# ## Full Categorization

# %%
full_categorization, full_labels = utils.mark_cell_categories(cell_labels, 'Full')
full_clusters = utils.apply_kmeans(12, tables_a)
utils.plot_clusters(tables_a, full_clusters,full_categorization, full_labels)

# %%
full_categorization, full_labels = utils.mark_cell_categories(cell_labels, 'Full')
full_clusters = utils.agglom_clust(12, tables_a)
utils.plot_clusters(tables_a, full_clusters,full_categorization, full_labels)

# %% [markdown]
# ## DB Subtype Categorization

# %%
dbsub_categorization, dbsub_labels = utils.mark_cell_categories(cell_labels, 'DB_Subtypes')
dsub_clusters = utils.apply_kmeans(12, tables_a)
utils.plot_clusters(tables_a, dsub_clusters, dbsub_categorization, dbsub_labels)

# %%
dsub_clusters = utils.agglom_clust(12, tables_a)
utils.plot_clusters(tables_a, dsub_clusters, dbsub_categorization, dbsub_labels)

# %% [markdown]
# # Quantitative measure of clustering success

# %%
from sklearn.utils.linear_assignment_ import linear_assignment

y_
y_true = y.astype(np.int64)
D = max(y_pred.max(), y_true.max()) + 1
w = np.zeros((D, D), dtype=np.int64)
# Confusion matrix.
for i in range(y_pred.size):
    w[y_pred[i], y_true[i]] += 1
ind = linear_assignment(-w)
acc = sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2f9672ba74e1> in <module>()
#       1 from sklearn.utils.linear_assignment_ import linear_assignment
#       2
# ----> 3 y_true = y.astype(np.int64)
#       4 D = max(y_pred.max(), y_true.max()) + 1
#       5 w = np.zeros((D, D), dtype=np.int64)
#
# NameError: name 'y' is not defined
